# %%
using Plots;

# %%
randn()

# %%
n = 100
ϵ = randn(n)
plot(1:n, ϵ)

# %%
import Pkg; Pkg.add("Plots")

# %%
using Plots
gr(fmt=:png); # setting for easier display in jupyter notebooks

n = 100
ϵ = randn(n)
plot(1:n, ϵ)

# %%
using GLPK

# %%
using Plots

# %%
using JuMP;

# %%
using IJulia;

# %%
] st
# Out:
#       Status `/srv/julia-1.7.2/depot/environments/v1.7/Project.toml`
#   [587475ba] Flux v0.12.4
#   [60bf3e95] GLPK v1.0.1
#   [7073ff75] IJulia v1.23.2
#   [4076af6c] JuMP v0.23.2
#   [2774e3e8] NLsolve v4.5.1
#   [91a5bcdd] Plots v1.27.1

# %%
ENV["COLUMNS"] = 200 # wide output is OK
ENV["LINES"] = 15; # but we do not want it to be overly tall
cd(@__DIR__)
using Pkg
Pkg.activate(".")
Pkg.status()

# %%
ENV

# %%
Pkg.status()
# Out:
# UndefVarError: Pkg not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[1]:1
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
using Plots

# %%
] st
# Out:
#       Status `/srv/julia-1.7.2/depot/environments/v1.7/Project.toml`
#   [587475ba] Flux v0.12.4
#   [60bf3e95] GLPK v1.0.1
#   [7073ff75] IJulia v1.23.2
#   [4076af6c] JuMP v0.23.2
#   [2774e3e8] NLsolve v4.5.1
#   [91a5bcdd] Plots v1.27.1

# %%
using Pkg

# %%
Pkg.status()
# Out:
#       Status `/srv/julia-1.7.2/depot/environments/v1.7/Project.toml`
#   [60bf3e95] GLPK v1.0.1
#   [7073ff75] IJulia v1.23.2
#   [4076af6c] JuMP v0.23.2
#   [91a5bcdd] Plots v1.27.1

# %%
using Pkg; print(Pkg.envdir(DEPOT_PATH[1]))'
# Out:
# /export/home/users/Enseignants/antoine.rozenknop/.julia/environments
# MethodError: no method matching adjoint(::Nothing)
# Closest candidates are:
#   adjoint(::Union{LinearAlgebra.QR, LinearAlgebra.QRCompactWY, LinearAlgebra.QRPivoted}) at /srv/julia-1.7.2/share/julia/stdlib/v1.7/LinearAlgebra/src/qr.jl:509
#   adjoint(::Union{LinearAlgebra.Cholesky, LinearAlgebra.CholeskyPivoted}) at /srv/julia-1.7.2/share/julia/stdlib/v1.7/LinearAlgebra/src/cholesky.jl:538
#   adjoint(::LinearAlgebra.SVD) at /srv/julia-1.7.2/share/julia/stdlib/v1.7/LinearAlgebra/src/svd.jl:262
#   ...
#
# Stacktrace:
#  [1] top-level scope
#    @ In[6]:1
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
using IJulia

# %%
using GLPK

# %%
using Plots

# %%
] st
# Out:
#       Status `/srv/julia-1.7.2/depot/environments/v1.7/Project.toml`
#   [587475ba] Flux v0.12.4
#   [60bf3e95] GLPK v1.0.1
#   [87dc4568] HiGHS v1.1.1
#   [7073ff75] IJulia v1.23.2
#   [4076af6c] JuMP v0.23.2
#   [2774e3e8] NLsolve v4.5.1
#   [91a5bcdd] Plots v1.27.1
#   [82193955] SCIP v0.10.2

# %%
using NLsolve

# %%
using Flux

# %%
using SCIP

# %%
using HiGHS
